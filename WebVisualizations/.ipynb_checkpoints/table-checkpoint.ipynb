# %%
import pandas as pd

# create dataframe
mycsv = ".\\Resources\\cities.csv"

cities_df = pd.read_csv(mycsv)

html_table = cities_df.to_html()

print (html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Datetime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Srednekolymsk</td>
#       <td>67.45</td>
#       <td>153.68</td>
#       <td>-10.08</td>
#       <td>90</td>
#       <td>97</td>
#       <td>8.05</td>
#       <td>RU</td>
#       <td>1605588318</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Araceli</td>
#       <td>10.55</td>
#       <td>119.99</td>
#       <td>83.89</td>
#       <td>80</td>
#       <td>77</td>
#       <td>15.14</td>
#       <td>PH</td>
#       <td>1605588318</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...
